# %% [markdown]
# <a href="https://colab.research.google.com/github/bluepaper14/bluepaper14/blob/main/practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Heollo world")
# Out:
# Heollo world
